# %% [markdown]
# # Module 5 — Simple Sorting
#
# This is the worked reference notebook: run live in lecture, fully solved.
# The version students receive with TODOs in place of the solved parts is
# `assignments/pds/a4-simple-sorting/starter/simple_sorting.py`.

# %% [markdown]
# ## 1. Bubble sort and selection sort (Lecture 1)

# %%
def bubble_sort(arr):
    arr = arr[:]
    n = len(arr)
    for i in range(n - 1):
        swapped = False
        for j in range(n - 1 - i):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swapped = True
        if not swapped:
            break
    return arr

def selection_sort(arr):
    arr = arr[:]
    n = len(arr)
    for i in range(n - 1):
        min_idx = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr

assert bubble_sort([5, 2, 4, 1, 3]) == [1, 2, 3, 4, 5]
assert selection_sort([5, 2, 4, 1, 3]) == [1, 2, 3, 4, 5]
print("Bubble sort and selection sort checks passed, matching Lecture 1's traces")
# Out:
# Bubble sort and selection sort checks passed, matching Lecture 1's traces

# %% [markdown]
# ## 2. Insertion sort and inversion counting (Lecture 2)

# %%
def insertion_sort(arr):
    arr = arr[:]
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr

def count_inversions(arr):
    n = len(arr)
    count = 0
    for i in range(n):
        for j in range(i + 1, n):
            if arr[i] > arr[j]:
                count += 1
    return count

assert insertion_sort([5, 2, 4, 1, 3]) == [1, 2, 3, 4, 5]
assert insertion_sort([1, 2, 3, 5, 4]) == [1, 2, 3, 4, 5]
assert count_inversions([1, 2, 3, 5, 4]) == 1   # matches Lecture 2's exact trace
assert count_inversions([6, 5, 4, 3, 2, 1]) == 15  # n(n-1)/2 for n=6, every pair inverted
print("Insertion sort and inversion counting checks passed, matching Lecture 2's exact results")
# Out:
# Insertion sort and inversion counting checks passed, matching Lecture 2's exact results

# %% [markdown]
# ## 3. Counting sort, stable (Lecture 3)

# %%
def counting_sort(arr, k):
    count = [0] * (k + 1)
    for x in arr:
        count[x] += 1
    for i in range(1, k + 1):
        count[i] += count[i - 1]
    output = [0] * len(arr)
    for x in reversed(arr):
        count[x] -= 1
        output[count[x]] = x
    return output

assert counting_sort([2, 5, 3, 0, 2, 3], 5) == [0, 2, 2, 3, 3, 5]

# Stability check using tagged tuples, sorted by first element only
def counting_sort_tagged(pairs, k):
    count = [0] * (k + 1)
    for key, _ in pairs:
        count[key] += 1
    for i in range(1, k + 1):
        count[i] += count[i - 1]
    output = [None] * len(pairs)
    for key, tag in reversed(pairs):
        count[key] -= 1
        output[count[key]] = (key, tag)
    return output

tagged = [(3, "a"), (3, "b"), (1, "c")]
result = counting_sort_tagged(tagged, 3)
assert result == [(1, "c"), (3, "a"), (3, "b")]   # 'a' still precedes 'b' — stable
print("Counting sort checks passed, stability confirmed")
# Out:
# Counting sort checks passed, stability confirmed

# %% [markdown]
# ## 4. Radix sort (Lecture 3)

# %%
def counting_sort_by_digit(arr, exp):
    n = len(arr)
    output = [0] * n
    count = [0] * 10
    for x in arr:
        digit = (x // exp) % 10
        count[digit] += 1
    for i in range(1, 10):
        count[i] += count[i - 1]
    for x in reversed(arr):
        digit = (x // exp) % 10
        count[digit] -= 1
        output[count[digit]] = x
    return output

def radix_sort(arr):
    if not arr:
        return arr
    max_val = max(arr)
    exp = 1
    result = arr[:]
    while max_val // exp > 0:
        result = counting_sort_by_digit(result, exp)
        exp *= 10
    return result

assert radix_sort([170, 45, 75, 90, 802, 24, 2]) == [2, 24, 45, 75, 90, 170, 802]

import random
random_data = [random.randint(0, 999999) for _ in range(2000)]
assert radix_sort(random_data) == sorted(random_data)
print("Radix sort checks passed, matching Lecture 3's trace and Python's sorted()")
# Out:
# Radix sort checks passed, matching Lecture 3's trace and Python's sorted()

# %% [markdown]
# ## 5. The decision-tree lower bound, checked numerically (Lecture 4)

# %%
import math

def min_comparisons_needed(n):
    return math.ceil(math.log2(math.factorial(n)))

assert min_comparisons_needed(3) == 3   # 3! = 6, log2(6) ~= 2.58, ceil = 3
assert min_comparisons_needed(8) > 10   # confirms Lecture 4's quiz: 10 comparisons is not enough for n=8
assert min_comparisons_needed(4) > 4    # confirms Lecture 4's second quiz: 4 comparisons is not enough for n=4
print("Decision-tree lower bound checks passed, matching Lecture 4's quiz answers")
print("min comparisons needed for n=8:", min_comparisons_needed(8))
print("min comparisons needed for n=4:", min_comparisons_needed(4))
# Out:
# Decision-tree lower bound checks passed, matching Lecture 4's quiz answers
# min comparisons needed for n=8: 16
# min comparisons needed for n=4: 5
